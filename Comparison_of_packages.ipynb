000, 90000, 100000, 110000, 120000, 130000, 140000, 150000, 160000, 170000, 180000]

# %%
contT_LB = [0.28800011, 0.37899995, 0.45000005, 0.49300003, 0.5400002 ,0.59299994, 0.6559999 , 0.69099998, 0.7809999 , 0.82500005,0.86199999, 0.93099999, 0.97899985, 1.04399991, 1.125     ,1.18200016, 1.35699987, 1.41100001]

contMAE_LB = [1814.94582255, 1763.19446601, 1784.91742558, 1765.46749676,1778.17436367, 1728.81254559, 1765.35260552, 1728.97892376,1772.49439756, 1759.56026182, 1748.99894566, 1737.72413971,1744.66348186, 1747.42878141, 1741.14623924, 1755.12406333,1750.79223979, 1752.82307617]

contN_LB = [ 10000,  20000,  30000,  40000,  50000,  60000,  70000,  80000, 90000, 100000, 110000, 120000, 130000, 140000, 150000, 160000, 170000, 180000]

# %%
T_CB = [101.0416967868805, 152.92073488235474, 192.10053992271423, 278.4166090488434,320.35343623161316,375.2232551574707,418.0883209705353,457.95433807373047,492.5287652015686,567.1065368652344,619.5699310302734,651.1002008914948,688.0186049938202,760.2240178585052,868.701425075531,915.0646908283234,966.58043384552,1006.02202177]

MAE_CB = [1199.5237160927704,1188.5541050441057,1173.7938188583867,1152.594144438634,1159.9721018018627,1140.9935944224549,1142.8246960383758,1131.1222899764873,1151.8027462274313,1143.3617396265213,1140.468019443178,1134.1484863275573,1143.2230264072211,1146.543833516472,1124.7417676171665,1137.1607908383971,1137.1065584904616,1139.436760]

N_CB = N

# %%
catT_CB = [142.27282571792603,138.49478578567505,178.01026701927185,302.47490215301514,350.9883053302765,398.1485197544098,466.3825981616974,523.8505449295044, 649.449206829071,871.8361840248108,726.6249902248383,712.0554268360138,797.1459889411926,851.6005229949951,929.696751832962, 957.55285, 968.599789, 993.527950]

catMAE_CB = [1211.16346656116,1200.239921342969,1193.3017971085446,1170.545223586372,1177.470247087185,1161.2252111126884,1159.1163298518136,1150.7634700528129,1171.961083129178,1164.5034863336687,1154.2204680118496,1149.4824634411887,1162.3307132173568,1161.4697673030075,1142.0245763248836,1155.0554825538288,1157.7755898669886, 1157.885340]

catN_CB = N

# %%
contT_CB = [11.832312107086182,12.985090017318726,10.501464128494263,13.022104024887085,16.582520008087158,13.118649959564209,13.331664085388184,18.406954050064087,20.043365001678467,25.953584671020508,21.104858875274658,23.458249807357788,26.114973306655884,22.674687147140503, 25.286484241485596, 26.954382, 23.744405, 25.616213]

contMAE_CB = [1793.4498511280888,1758.3492367610675,1779.6111004840766,1755.5806395050113,1774.4886886379666,1727.209940085353,1764.4626533725082,1727.6817715838192,1770.9161113882178,1757.6157229765265,1748.5161575895427,1736.804158759494,1744.2114823479633,1748.8508733890144,1741.4875925904148,1755.7830632610687,1751.5669757456758, 1753.813515]

contN_CB = N

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111)
ax.plot(N_XG, T_XG, 'red', label = 'XGBoost')
ax.plot(N_XG, T_XG, 'ro')
ax.plot(N_CB, T_CB, 'go')
ax.plot(N_CB, T_CB, 'green', label = 'CatBoost')
ax.plot(N_LB, T_LB, 'mo')
ax.plot(N_LB, T_LB, 'magenta', label = 'LightGBM')
ax.set_title('Time taken for Optimal XGBoost, LightGBM and CatBoost', size = 20)
ax.set_xlabel('Number of data',fontsize = 14 )
ax.set_ylabel('Time (seconds)',fontsize = 14)
ax.legend(prop={'size': 20})
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111)
ax.plot(catN_XG, catT_XG, 'red', label = 'XGBoost')
ax.plot(catN_XG, catT_XG, 'ro')
ax.plot(catN_CB, catT_CB, 'go')
ax.plot(catN_CB, catT_CB, 'green', label = 'CatBoost')
ax.plot(catN_LB, catT_LB, 'mo')
ax.plot(catN_LB, catT_LB, 'magenta', label = 'LightGBM')
ax.set_title('Time taken for XGBoost, LightGBM & CatBoost (Categorical)', size = 20)
ax.set_xlabel('Number of data',fontsize = 14 )
ax.set_ylabel('Time (seconds)',fontsize = 14)
ax.legend(prop={'size': 20})
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111)
ax.plot(contN_XG, contT_XG, 'red', label = 'XGBoost')
ax.plot(contN_XG, contT_XG, 'ro')
ax.plot(contN_CB, contT_CB, 'go')
ax.plot(contN_CB, contT_CB, 'green', label = 'CatBoost')
ax.plot(contN_LB, contT_LB, 'mo')
ax.plot(contN_LB, contT_LB, 'magenta', label = 'LightGBM')
ax.set_title('Time taken for XGBoost, LightGBM & CatBoost (Continuous)', size = 20)
ax.set_xlabel('Number of data',fontsize = 14 )
ax.set_ylabel('Time (seconds)',fontsize = 14)
ax.legend(prop={'size': 20})
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111)
ax.plot(N_XG, MAE_XG, 'ro')
ax.plot(N_XG, MAE_XG, 'red', label = 'XGBoost')
ax.plot(N_CB, MAE_CB, 'go')
ax.plot(N_CB, MAE_CB, 'green', label = 'CatBoost')
ax.plot(N_LB, MAE_LB, 'mo')
ax.plot(N_LB, MAE_LB, 'magenta', label = 'LightGBM')
ax.set_title('Accuracy for XGBoost, LightGBM & CatBoost', size = 20)
ax.set_xlabel('Number of data', fontsize = 14 )
ax.set_ylabel('Mean absolute error (aU)',fontsize = 14)
ax.legend(prop={'size': 20})
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111)
ax.plot(catN_XG, catMAE_XG, 'ro')
ax.plot(catN_XG, catMAE_XG, 'red', label = 'XGBoost')
ax.plot(catN_CB, catMAE_CB, 'go')
ax.plot(catN_CB, catMAE_CB, 'green', label = 'CatBoost')
ax.plot(catN_LB, catMAE_LB, 'mo')
ax.plot(catN_LB, catMAE_LB, 'magenta', label = 'LightGBM')
ax.set_title('Accuracy for XGBoost, LightGBM & CatBoost (Categorical)', size = 20)
ax.set_xlabel('Number of data', fontsize = 14 )
ax.set_ylabel('Mean absolute error (aU)',fontsize = 14)
ax.legend(prop={'size': 20})
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111)
ax.plot(contN_XG, contMAE_XG, 'ro')
ax.plot(contN_XG, contMAE_XG, 'red', label = 'XGBoost')
ax.plot(contN_CB, contMAE_CB, 'go')
ax.plot(contN_CB, contMAE_CB, 'green', label = 'CatBoost')
ax.plot(contN_LB, contMAE_LB, 'mo')
ax.plot(contN_LB, contMAE_LB, 'magenta', label = 'LightGBM')
ax.set_title('Accuracy for XGBoost, LightGBM & CatBoost (Continuous)', size = 20)
ax.set_xlabel('Number of data', fontsize = 14 )
ax.set_ylabel('Mean absolute error (aU)',fontsize = 14)
ax.legend(prop={'size': 20})
plt.show()
